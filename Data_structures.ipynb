# %% [markdown]
# <a href="https://colab.research.google.com/github/H3nr7M/Data_structures_notes/blob/main/Data_structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data structures
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Data structures
# * list
# * linked list
# * Hash tables
# * Tails
# * Queue
# * Trees
# * Heaps
